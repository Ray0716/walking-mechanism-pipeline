# %%
import numpy as np

# Set the random seed for reproducibility 
#np.random.seed(42)

# shape of init pos 

np.random.seed(48)
types   = ['Type823-']
initPos = [22]


# Generate random float values
min_value = -10.0
max_value = 10.0

i = 0

print(types[i], initPos[i])


shape = (6000000, initPos[i])
random_values = np.random.uniform(min_value, max_value, shape)
np.save("./npy-inputs/" + types[i], random_values)
# Out:
# Steph3T2A2 16

# %%
ls
# Out:
# '0.0 random init state copy.ipynb'  '1.0 Server0.ipynb'
# '0.5 utils.ipynb'                    npy-inputs/

# %%
np.random.seed(100)
shape = (100000, 14)
random_values = np.random.uniform(min_value, max_value, shape)
np.save('Stephensen2many', random_values)
