# %%
import numpy as np 

a = [[1, 2, 3], [4, 5, 6], ['sLA', 'ZBBB', 'JZZZZZ']]

np.array(a).shape

initStates = np.load("./npy-inputs/" + 'RandPos-.npy')

initStates.shape
# Out:
# (10000000, 22)

# %%
import numpy as np
import tqdm

# Set the random seed for reproducibility 
#np.random.seed(42)

# shape of init pos 

np.random.seed(78)
types   = ['RandPos-']
initPos = [22]


# Generate random float values
min_value = -10.0
max_value = 10.0

i = 0

print(types[i], initPos[i])


shape = (100000000, initPos[i])
random_values = np.random.uniform(min_value, max_value, shape)
np.save("/gpfs/scratch/raytang/walking-dataset-generator-old-simulator/Image-method-Synthesis-main/npy-inputs/" + types[i], random_values)
# Out:
# RandPos- 22

# %%
test = np.load("/gpfs/scratch/raytang/walking-dataset-generator-old-simulator/Image-method-Synthesis-main/npy-inputs/RandPos-.npy")
print(test.shape)
# Out:
# (100000000, 22)

# %%
np.random.seed(100)
shape = (1000000, 14)
random_values = np.random.uniform(min_value, max_value, shape)
#np.save('Stephensen2many', random_values)

# %%
random_values.shape
# Out:
# (100000000, 22)
